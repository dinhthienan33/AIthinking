# %%
# !pip install openai
# !pip install langchain
# !pip install langchain-openai
# !pip install PyPDF2
# !pip install langchain-community faiss-gpu
# !pip install langchain-google-genai
# Out:
# Collecting langchain
#   Downloading langchain-0.3.13-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in d:\anaconda\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\anaconda\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\anaconda\lib\site-packages (from langchain) (3.9.5)
# Collecting langchain-core<0.4.0,>=0.3.26 (from langchain)
#   Downloading langchain_core-0.3.28-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.3 (from langchain)
#   Downloading langchain_text_splitters-0.3.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.3,>=0.1.17 (from langchain)
#   Downloading langsmith-0.2.6-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in d:\anaconda\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain) (2.7.4)
# Requirement already satisfied: requests<3,>=2 in d:\anaconda\lib\site-packages (from langchain) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.26->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain) (2.1)
# Downloading langchain-0.3.13-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.0 MB 525.1 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.0 MB 1.3 MB/s eta 0:00:01
#    ------------ --------------------------- 0.3/1.0 MB 1.7 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.6 MB/s eta 0:00:00
# Downloading langchain_core-0.3.28-py3-none-any.whl (411 kB)
#    ---------------------------------------- 0.0/411.6 kB ? eta -:--:--
#    ---------------------------------------- 411.6/411.6 kB 8.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.4-py3-none-any.whl (27 kB)
# Downloading langsmith-0.2.6-py3-none-any.whl (325 kB)
#    ---------------------------------------- 0.0/325.7 kB ? eta -:--:--
#    --------------------------------------- 325.7/325.7 kB 19.7 MB/s eta 0:00:00
# Installing collected packages: langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed langchain-0.3.13 langchain-core-0.3.28 langchain-text-splitters-0.3.4 langsmith-0.2.6
# Collecting langchain-openai
#   Downloading langchain_openai-0.2.14-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in d:\anaconda\lib\site-packages (from langchain-openai) (0.3.28)
# Collecting openai<2.0.0,>=1.58.1 (from langchain-openai)
#   Downloading openai-1.58.1-py3-none-any.whl.metadata (27 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.8.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (0.2.6)
# Requirement already satisfied: packaging<25,>=23.2 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (2.7.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (8.2.2)
# Requirement already satisfied: typing-extensions>=4.7 in d:\anaconda\lib\site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-openai) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anaconda\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.58.1->langchain-openai)
#   Downloading jiter-0.8.2-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in d:\anaconda\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain-openai) (4.66.4)
# Requirement already satisfied: regex>=2022.1.18 in d:\anaconda\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in d:\anaconda\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.2)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain-openai) (3.7)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.58.1->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-openai) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-openai) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.27->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.27->langchain-openai) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.2)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.58.1->langchain-openai) (0.4.6)
# Downloading langchain_openai-0.2.14-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/50.9 kB ? eta -:--:--
#    ---------------------------------------- 50.9/50.9 kB 864.6 kB/s eta 0:00:00
# Downloading openai-1.58.1-py3-none-any.whl (454 kB)
#    ---------------------------------------- 0.0/454.3 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/454.3 kB 3.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 194.6/454.3 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 454.3/454.3 kB 3.6 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp312-cp312-win_amd64.whl (883 kB)
#    ---------------------------------------- 0.0/883.8 kB ? eta -:--:--
#    ---------------------- ---------------- 512.0/883.8 kB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  880.6/883.8 kB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 883.8/883.8 kB 9.3 MB/s eta 0:00:00
# Downloading jiter-0.8.2-cp312-cp312-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.7 kB ? eta -:--:--
#    --------------------------------------- 204.7/204.7 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: jiter, tiktoken, openai, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.35.3
#     Uninstalling openai-1.35.3:
#       Successfully uninstalled openai-1.35.3
# Successfully installed jiter-0.8.2 langchain-openai-0.2.14 openai-1.58.1 tiktoken-0.8.0
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/232.6 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/232.6 kB 330.3 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/232.6 kB 330.3 kB/s eta 0:00:01
#    --------------- ----------------------- 92.2/232.6 kB 525.1 kB/s eta 0:00:01
#    -------------------------------------- - 225.3/232.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 232.6/232.6 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting langchain-community
#   Downloading langchain_community-0.3.13-py3-none-any.whl.metadata (2.9 kB)
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.0.7-py3-none-any.whl.metadata (3.6 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-generativeai<0.9.0,>=0.8.0 (from langchain-google-genai)
#   Using cached google_generativeai-0.8.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3.15 in d:\anaconda\lib\site-packages (from langchain-google-genai) (0.3.28)
# Requirement already satisfied: pydantic<3,>=2 in d:\anaconda\lib\site-packages (from langchain-google-genai) (2.7.4)
# Collecting google-ai-generativelanguage==0.6.10 (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai)
#   Using cached google_ai_generativelanguage-0.6.10-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core in d:\anaconda\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.20.0)
# Requirement already satisfied: google-api-python-client in d:\anaconda\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.147.0)
# Requirement already satisfied: google-auth>=2.15.0 in d:\anaconda\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.35.0)
# Requirement already satisfied: protobuf in d:\anaconda\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.25.5)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.66.4)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in d:\anaconda\lib\site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.24.0)
# Requirement already satisfied: PyYAML>=5.3 in d:\anaconda\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\anaconda\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in d:\anaconda\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.2.6)
# Requirement already satisfied: packaging<25,>=23.2 in d:\anaconda\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (23.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-genai) (8.2.2)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in d:\anaconda\lib\site-packages (from pydantic<3,>=2->langchain-google-genai) (2.18.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in d:\anaconda\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in d:\anaconda\lib\site-packages (from google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.32.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.9)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.15->langchain-google-genai) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.0.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in d:\anaconda\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in d:\anaconda\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in d:\anaconda\lib\site-packages (from google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (4.1.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.66.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in d:\anaconda\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (3.0.9)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (4.2.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.0.6)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (3.7)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-genai) (0.14.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai<0.9.0,>=0.8.0->langchain-google-genai) (2.2.2)
# Downloading langchain_google_genai-2.0.7-py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/41.3 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/41.3 kB ? eta -:--:--
#    ------------------- -------------------- 20.5/41.3 kB 217.9 kB/s eta 0:00:01
#    ---------------------------------------  41.0/41.3 kB 279.3 kB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 kB 248.8 kB/s eta 0:00:00
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_generativeai-0.8.3-py3-none-any.whl (160 kB)
# Using cached google_ai_generativelanguage-0.6.10-py3-none-any.whl (760 kB)
# Installing collected packages: filetype, google-ai-generativelanguage, google-generativeai, langchain-google-genai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.4
#     Uninstalling google-ai-generativelanguage-0.6.4:
#       Successfully uninstalled google-ai-generativelanguage-0.6.4
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.6.0
#     Uninstalling google-generativeai-0.6.0:
#       Successfully uninstalled google-generativeai-0.6.0
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.6.10 google-generativeai-0.8.3 langchain-google-genai-2.0.7

# %%
from PyPDF2 import PdfReader
from langchain.embeddings.base import Embeddings
from langchain.text_splitter import CharacterTextSplitter
from sentence_transformers import SentenceTransformer
import numpy as np
from langchain.vectorstores import FAISS
# Out:
# WARNING:tensorflow:From d:\anaconda\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
store = None

class STEmbeddings(Embeddings):
    def __init__(self, model_name="thenlper/gte-large"):
        self.model = SentenceTransformer(model_name)

    def embed_documents(self, texts):
        embeddings = self.model.encode(texts)
        return embeddings.tolist()

    def embed_query(self, text):
        embedding = self.model.encode(text)
        return embedding.tolist()

embeddings = STEmbeddings()

def split_paragraphs(rawText):
    text_splitter = CharacterTextSplitter(
        separator="\n",
        chunk_size=1000,
        chunk_overlap=200,
        length_function=len,
        is_separator_regex=False,
    )

    return  text_splitter.split_text(rawText)

def load_pdfs(pdfs):
    text_chunks = []

    for pdf in pdfs:
        reader = PdfReader(pdf)
        for page in reader.pages:
            raw = page.extract_text()
            chunks = split_paragraphs(raw)
            text_chunks += chunks
    return text_chunks

# %%
def main():
    list_of_pdfs = ["data\GT học phần Tư tưởng HCM (K) Tr69 -Tr141.pdf"]
    text_chunks = load_pdfs(list_of_pdfs)

    # Index the text chunks in our FAISS store.
    # OpenAIEmbeddings will be used automatically to convert
    # Each chunk of text into vector embeddings using
    # OpenAI APIs.
    store = FAISS.from_texts(text_chunks, embeddings)

    # Write our index to disk.
    store.save_local("./vectorstore")

main()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\APTS\AppData\Local\Temp\ipykernel_11604\1078472732.py:2: SyntaxWarning: invalid escape sequence '\G'
#   list_of_pdfs = ["data\GT học phần Tư tưởng HCM (K) Tr69 -Tr141.pdf"]
# C:\Users\APTS\AppData\Local\Temp\ipykernel_11604\1078472732.py:2: SyntaxWarning: invalid escape sequence '\G'
#   list_of_pdfs = ["data\GT học phần Tư tưởng HCM (K) Tr69 -Tr141.pdf"]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\anaconda\Lib\site-packages\langchain_community\vectorstores\faiss.py:56, in dependable_faiss_import(no_avx2)
#      55     else:
# ---> 56         import faiss
#      57 except ImportError:
#
# ModuleNotFoundError: No module named 'faiss'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 14
#      11     # Write our index to disk.
#      12     store.save_local("./vectorstore")
# ---> 14 main()
#
# Cell In[10], line 9, in main()
#       3 text_chunks = load_pdfs(list_of_pdfs)
#       5 # Index the text chunks in our FAISS store.
#       6 # OpenAIEmbeddings will be used automatically to convert
#       7 # Each chunk of text into vector embeddings using
#       8 # OpenAI APIs.
# ----> 9 store = FAISS.from_texts(text_chunks, embeddings)
#      11 # Write our index to disk.
#      12 store.save_local("./vectorstore")
#
# File d:\anaconda\Lib\site-packages\langchain_community\vectorstores\faiss.py:1044, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1025 """Construct FAISS wrapper from raw documents.
#    1026
#    1027 This is a user friendly interface that:
#    (...)
#    1041         faiss = FAISS.from_texts(texts, embeddings)
#    1042 """
#    1043 embeddings = embedding.embed_documents(texts)
# -> 1044 return cls.__from(
#    1045     texts,
#    1046     embeddings,
#    1047     embedding,
#    1048     metadatas=metadatas,
#    1049     ids=ids,
#    1050     **kwargs,
#    1051 )
#
# File d:\anaconda\Lib\site-packages\langchain_community\vectorstores\faiss.py:996, in FAISS.__from(cls, texts, embeddings, embedding, metadatas, ids, normalize_L2, distance_strategy, **kwargs)
#     984 @classmethod
#     985 def __from(
#     986     cls,
#    (...)
#     994     **kwargs: Any,
#     995 ) -> FAISS:
# --> 996     faiss = dependable_faiss_import()
#     997     if distance_strategy == DistanceStrategy.MAX_INNER_PRODUCT:
#     998         index = faiss.IndexFlatIP(len(embeddings[0]))
#
# File d:\anaconda\Lib\site-packages\langchain_community\vectorstores\faiss.py:58, in dependable_faiss_import(no_avx2)
#      56         import faiss
#      57 except ImportError:
# ---> 58     raise ImportError(
#      59         "Could not import faiss python package. "
#      60         "Please install it with `pip install faiss-gpu` (for CUDA supported GPU) "
#      61         "or `pip install faiss-cpu` (depending on Python version)."
#      62     )
#      63 return faiss
#
# ImportError: Could not import faiss python package. Please install it with `pip install faiss-gpu` (for CUDA supported GPU) or `pip install faiss-cpu` (depending on Python version).

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# from langchain_community.chat_models import ChatOpenAI
from langchain_community.vectorstores import FAISS
# from langchain_community.embeddings import OpenAIEmbeddings
from langchain.chains import RetrievalQA
from langchain_google_genai import ChatGoogleGenerativeAI


store = FAISS.load_local("vectorstore",  embeddings, allow_dangerous_deserialization=True)


class SimpleRetrievalQA:
    def __init__(self, retriever):
        self.retriever = retriever

    def run(self, query):
        retrieved_docs = self.retriever.get_relevant_documents(query)

        # Generate a response from retrieved documents
        if not retrieved_docs:
            return {"answer": "No relevant information found."}

        # Example: Return the content of the first retrieved document
        return {"answer": retrieved_docs[0].page_content}


# Replacing openai with gemini
# llm = ChatGoogleGenerativeAI(
#     model="gemini-1.5-pro",
#     temperature=0,
#     google_api_key="AIzaSyDU5w4BHDCzovzRG2cyEbqXdYXyfnmIstU"
# )

# chain = RetrievalQA.from_chain_type(
#    llm=None,
#    retriever=store.as_retriever()
# )
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
retriever = store.as_retriever()

# Initialize custom RetrievalQA
chain = SimpleRetrievalQA(retriever)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
query = "Range function in python?"
result = chain.run(query)
print(result['answer'])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Python Tutorial, Release 3.7.0
# >>>print(range(10))
# range(0, 10)
# In many ways the object returned by range() behaves as if it is a list, but in fact it isn’t. It is an object
# which returns the successive items of the desired sequence when you iterate over it, but it doesn’t really
# make the list, thus saving space.
# We say such an object is iterable, that is, suitable as a target for functions and constructs that expect
# something from which they can obtain successive items until the supply is exhausted. We have seen that
# theforstatement is such an iterator. The function list()is another; it creates lists from iterables:
# >>>list(range(5))
# [0, 1, 2, 3, 4]
# Later we will see more functions that return iterables and take iterables as argument.
# 4.4 breakand continue Statements, and elseClauses on Loops
# Thebreakstatement, like in C, breaks out of the innermost enclosing fororwhileloop.
# Loop statements may have an elseclause; it is executed when the loop terminates through exhaustion of

# %%
from langchain_community.vectorstores import FAISS
# from langchain_community.embeddings import OpenAIEmbeddings
from langchain.chains import RetrievalQA
from langchain_google_genai import ChatGoogleGenerativeAI


store = FAISS.load_local("vectorstore",  embeddings, allow_dangerous_deserialization=True)

# Replacing openai with gemini
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    google_api_key="AIzaSyDU5w4BHDCzovzRG2cyEbqXdYXyfnmIstU"
)

chain = RetrievalQA.from_chain_type(
   llm=llm,
   retriever=store.as_retriever()
)

# Ask the LLM a question.
result = chain({"query": "Range function in python?"})
print(result['result'])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# The `range()` function in Python generates a sequence of numbers.  It's often used in loops.  `range(10)` generates 10 values, from 0 up to (but not including) 10.  You can also specify a starting point and a step:  `range(5, 10)` generates numbers from 5 to 9, and `range(0, 10, 3)` generates 0, 3, 6, and 9.  While it behaves like a list in many ways, `range()` is actually an iterable, saving memory by generating values on demand.  You can convert it to a list using `list(range(5))`.
